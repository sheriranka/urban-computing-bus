# %% [markdown]
# ## import libraries

# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.cluster import KMeans, DBSCAN
from sklearn.mixture import GaussianMixture

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')


#sns.set_palette("husl")
#sns.color_palette("husl", 8)

# %% [markdown]
# ## read data and store

# %%
df = pd.read_csv("bus.csv")
df
# Out:
#       id        lat        lon     time      acce
# 0      8  18.404205 -66.046492  9:24:32  0.000000
# 1      9  18.404124 -66.047754  9:24:57  0.000000
# 2     10  18.404005 -66.048628  9:25:29  0.000000
# 3     11  18.403444 -66.049969  9:26:11  0.000000
# 4     12  18.404178 -66.050321  9:26:41  0.000000
# ..   ...        ...        ...      ...       ...
# 134  142  18.406040 -66.043050  9:26:39  4.818562
# 135  143  18.406276 -66.042767  9:27:56  0.000000
# 136  144  18.406932 -66.042834  9:28:50  0.000000
# 137  145  18.405189 -66.045067  9:31:21  6.632481
# 138  146  18.403613 -66.045553  9:32:12  4.676039
#
# [139 rows x 5 columns]

# %% [markdown]
# ## clean and fix data a bit

# %% [markdown]
# *Constants*

# %%
#seed for random vals
seed = 42
#num of stops
p = 14

# %% [markdown]
# *Set stops*

# %%
#estimate stops
km = KMeans(n_clusters=p, init='random', n_init=10, max_iter=20, random_state=seed)
loc = df[['lat','lon']]
km.fit(loc)
loc['label'] = km.labels_
sns.scatterplot(data=loc, x='lat', y='lon', hue='label',palette="tab20c")
sns.scatterplot(x=km.cluster_centers_[:, 0], y=km.cluster_centers_[:,1], color='red', marker='x')
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.title("KMeans - Stop Estimation")
plt.show()

# %%
#stop labels
#ADJUST THIS BASED ON KMEANS GRAPH
#LAST VALUE IS ALWAYS 15
p0 = [9,11,4,3,19,5,1,13,2,10,20,24,23,6,15]
#attach column and adjust names
print(loc["label"])
df['stop'] = loc['label'].apply( lambda d : p0[d])
# Out:
# 0      12
# 1      11
# 2      11
# 3       7
# 4       7
#        ..
# 134     1
# 135     1
# 136     8
# 137     0
# 138    10
# Name: label, Length: 139, dtype: int32

# %%
### UNUSED

# #spots 8 9 and 10 are too close, estimate better!
# locsub = loc[(loc["label"] > 7) & (loc["label"] < 11)]
# km = KMeans(n_clusters=2, init='random', n_init=200, max_iter=500, random_state=seed)
# km.fit(locsub)
# locsub['label'] = km.labels_
# sns.scatterplot(data=locsub, x='lat', y='lon', hue='label',palette="tab20c")
# sns.scatterplot(x=km.cluster_centers_[:, 0], y=km.cluster_centers_[:,1], color='red', marker='x')
# plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
# plt.title("KMeans - 8,9,10")
# plt.show()

# #there should be two stops between 5 and 0, adjust better!

# locs = loc[(loc["label"] == 5)  | (loc["label"] == 0)]
# km = KMeans(n_clusters=3, init='random', n_init=200, max_iter=500, random_state=seed)
# km.fit(locs)
# locs['label'] = km.labels_
# sns.scatterplot(data=locs, x='lat', y='lon', hue='label',palette="tab20c")
# sns.scatterplot(x=km.cluster_centers_[:, 0], y=km.cluster_centers_[:,1], color='red', marker='x')
# plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
# plt.title("KMeans - 5, 0")
# plt.show()

# #replace values in big labels column
# #removing 10
# x = [8, 9]
# y = locsub['label'].apply( lambda d : x[d])
# for i in y.index.values:
#     loc.iloc[i,loc.columns.get_loc('label')] = y.loc[i]
    
# #add 10 back
# x = [5, 10, 0]
# y = locs['label'].apply( lambda d : x[d])
# for i in y.index.values:
#     loc.iloc[i,loc.columns.get_loc('label')] = y.loc[i]

# #better estimation
# sns.scatterplot(data=loc, x='lat', y='lon', hue='label',palette="tab20c")
# plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
# plt.title("KMeans - Stop Estimation(Adjusted)")
# plt.show()

# %%
#drop incorrect data
df_rm = df[df.index < 26]
df = df.drop(df_rm.index, axis=0)
df = df.reset_index()

# %% [markdown]
# *Calculate times*

# %%
#elapsed time
elapsed = [0]
for i in range(1, len(df["time"])):
    t = pd.to_datetime(df["time"][i],format='%H:%M:%S') - pd.to_datetime(df["time"][i-1],format='%H:%M:%S')
    elapsed.append(t.total_seconds())

df['elapsed'] = elapsed

#add time -> seconds column
ts = df['time'].apply( lambda d : pd.to_datetime(d,format='%H:%M:%S'))
ts = ts.apply( lambda d : d.time() )
sc = ts.apply( lambda d : (d.hour * 60 + d.minute) * 60 + d.second)
df['time_Seconds'] = sc

#df['Time_Seconds'] = df['Time'].total_seconds()
df
# Out:
#      index   id        lat        lon     time      acce  stop  elapsed  \
# 0       26   34  18.403981 -66.046373  8:42:35  0.000000    23      0.0
# 1       27   35  18.404105 -66.048489  8:43:13  0.000000    24     38.0
# 2       28   36  18.404201 -66.049903  8:43:56  0.000000    13     43.0
# 3       29   37  18.405122 -66.050338  8:44:52  4.572018     6     56.0
# 4       30   38  18.406180 -66.050259  8:45:22  3.924368     5     30.0
# ..     ...  ...        ...        ...      ...       ...   ...      ...
# 108    134  142  18.406040 -66.043050  9:26:39  4.818562    11     49.0
# 109    135  143  18.406276 -66.042767  9:27:56  0.000000    11     77.0
# 110    136  144  18.406932 -66.042834  9:28:50  0.000000     2     54.0
# 111    137  145  18.405189 -66.045067  9:31:21  6.632481     9    151.0
# 112    138  146  18.403613 -66.045553  9:32:12  4.676039    20     51.0
#
#      time_Seconds
# 0           31355
# 1           31393
# 2           31436
# 3           31492
# 4           31522
# ..            ...
# 108         33999
# 109         34076
# 110         34130
# 111         34281
# 112         34332
#
# [113 rows x 9 columns]

# %% [markdown]
# *More cleaning*

# %%
#remove unnecessary columns
df = df.drop(columns=['id','acce','index'])

# %%
print(df.to_string())
# Out:
#            lat        lon     time  stop  elapsed  time_Seconds
# 0    18.403981 -66.046373  8:42:35    23      0.0         31355
# 1    18.404105 -66.048489  8:43:13    24     38.0         31393
# 2    18.404201 -66.049903  8:43:56    13     43.0         31436
# 3    18.405122 -66.050338  8:44:52     6     56.0         31492
# 4    18.406180 -66.050259  8:45:22     5     30.0         31522
# 5    18.407194 -66.049543  8:45:59     5     37.0         31559
# 6    18.406721 -66.049000  8:46:16     5     17.0         31576
# 7    18.406061 -66.048104  8:46:47     4     31.0         31607
# 8    18.406627 -66.046957  8:47:16     3     29.0         31636
# 9    18.406023 -66.044951   8:48:3    10     47.0         31683
# 10   18.406176 -66.043161  8:48:48    11     45.0         31728
# 11   18.407364 -66.043194  8:50:24     2     96.0         31824
# 12   18.406322 -66.043016  8:55:20    11    296.0         32120
# 13   18.404989 -66.045066  8:58:26     9    186.0         32306
# 66   18.406336 -66.048697  9:54:18     4     26.0         35658
# 67   18.406336 -66.048697  9:54:18     4      0.0         35658
# 68   18.406064 -66.047624  9:54:41     4     23.0         35681
# 69   18.406798 -66.046265  9:55:27     3     46.0         35727
# 70   18.406109 -66.044592  9:56:15    10     48.0         35775
# 71   18.406206 -66.043152   9:57:3    11     48.0         35823
# 72   18.407118 -66.041875  9:58:42     2     99.0         35922
# 73   18.406720 -66.043565   10:2:1    11    199.0         36121
# 74   18.405168 -66.045465  10:4:15     9    134.0         36255
# 75   18.403597 -66.045588  10:5:51    20     96.0         36351
# 76   18.403865 -66.046380  10:6:27    23     36.0         36387
# 77   18.404108 -66.046426  8:39:32    23  -5215.0         31172
# 78   18.404150 -66.048531   8:40:2    24     30.0         31202
# 79   18.404173 -66.050070  8:40:32    13     30.0         31232
# 80   18.403785 -66.045466   8:48:1    20    449.0         31681
# 81   18.403401 -66.046189  8:48:21    20     20.0         31701
# 82   18.404129 -66.048392  8:48:50    24     29.0         31730
# 83   18.403992 -66.046185   9:8:27    23   1177.0         32907
# 84   18.403970 -66.048608   9:8:54    24     27.0         32934
# 85   18.403413 -66.049875   9:9:21    13     27.0         32961
# 86   18.404676 -66.050257   9:10:3     6     42.0         33003
# 87   18.406328 -66.049923  9:10:33     5     30.0         33033
# 88   18.407184 -66.049494  9:10:48     5     15.0         33048
# 89   18.406615 -66.048767  9:11:14     4     26.0         33074
# 90   18.406068 -66.048201  9:11:39     4     25.0         33099
# 91   18.406567 -66.046662  9:12:36     3     57.0         33156
# 92   18.406085 -66.044940  9:13:12    10     36.0         33192
# 93   18.406172 -66.043111  9:15:10    11    118.0         33310
# 94   18.406137 -66.043552   9:16:6    11     56.0         33366
# 95   18.406924 -66.042956   9:17:4     2     58.0         33424
# 96   18.405291 -66.045657  9:19:53     9    169.0         33593
# 97   18.403878 -66.045547  9:21:17    20     84.0         33677
# 98   18.404034 -66.046314  9:21:39    23     22.0         33699
# 99   18.404335 -66.048155  9:22:11    24     32.0         33731
# 100  18.404132 -66.050154  9:22:44    13     33.0         33764
# 101  18.404732 -66.049805  9:23:18     6     34.0         33798
# 102  18.406320 -66.050147  9:23:45     5     27.0         33825
# 103  18.407204 -66.049470   9:24:9     5     24.0         33849
# 104  18.406409 -66.048474  9:24:30     4     21.0         33870
# 105  18.406559 -66.048591  9:24:51     4     21.0         33891
# 106  18.406823 -66.046967   9:25:6     3     15.0         33906
# 107  18.405984 -66.044880  9:25:50    10     44.0         33950
# 108  18.406040 -66.043050  9:26:39    11     49.0         33999
# 109  18.406276 -66.042767  9:27:56    11     77.0         34076
# 110  18.406932 -66.042834  9:28:50     2     54.0         34130
# 111  18.405189 -66.045067  9:31:21     9    151.0         34281
# 112  18.403613 -66.045553  9:32:12    20     51.0         34332

# %%
#fix more row issues
for index, row in df.iterrows():
    #if first run of stop 2 isnt after stop 1, replace with 15
    #arbitrary number
    if row['stop'] == 2 & df.iloc[index-1]['stop'] != 1:
        row['stop'] = 15  

#add new empty column
df['round_trip'] = pd.NA

#calculate times between full round stop

for s in p0:
    df_r = df[df['stop'] == s]
    df['round_trip'] = df_r.time_Seconds.diff(df_r.time_Seconds.shift())


#set negative times to NaN
df['elapsed'] = df['elapsed'].mask(df['elapsed'] < 0)
df['round_trip'] = df['round_trip'].mask(df['round_trip'] < 0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[77], line 15
#      13 for s in p0:
#      14     df_r = df[df['stop'] == s]
# ---> 15     df['round_trip'] = df_r.time_Seconds.diff(df_r.time_Seconds.shift())
#      18 #set negative times to NaN
#      19 df['elapsed'] = df['elapsed'].mask(df['elapsed'] < 0)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:3006, in Series.diff(self, periods)
#    2921 @doc(
#    2922     klass="Series",
#    2923     extra_params="",
#    (...)
#    2969 )
#    2970 def diff(self, periods: int = 1) -> Series:
#    2971     """
#    2972     First discrete difference of element.
#    2973
#    (...)
#    3004     {examples}
#    3005     """
# -> 3006     result = algorithms.diff(self._values, periods)
#    3007     return self._constructor(result, index=self.index, copy=False).__finalize__(
#    3008         self, method="diff"
#    3009     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\algorithms.py:1439, in diff(arr, n, axis)
#    1419 def diff(arr, n: int, axis: AxisInt = 0):
#    1420     """
#    1421     difference of n between self,
#    1422     analogous to s-s.shift(n)
#    (...)
#    1436     shifted
#    1437     """
# -> 1439     n = int(n)
#    1440     na = np.nan
#    1441     dtype = arr.dtype
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:230, in _coerce_method.<locals>.wrapper(self)
#     222     warnings.warn(
#     223         f"Calling {converter.__name__} on a single element Series is "
#     224         "deprecated and will raise a TypeError in the future. "
#    (...)
#     227         stacklevel=find_stack_level(),
#     228     )
#     229     return converter(self.iloc[0])
# --> 230 raise TypeError(f"cannot convert the series to {converter}")
#
# TypeError: cannot convert the series to <class 'int'>

# %% [markdown]
# ## observe data spread

# %%
df_c = df[['elapsed', 'Time_Seconds']]
cor = df_c.corr()
print("Correlation between Time and Time Elapsed")
print(cor)

scaler = StandardScaler()
df_cs = scaler.fit_transform(df_c.values)

sns.kdeplot(x=df["elapsed"], color='blue', label="Time elapsed")
sns.kdeplot(x=df_cs[:,0], color='red', label="Time elapsed standarized")
plt.legend(loc="upper left")
plt.title("Time elapsed distribution")
plt.show()

sns.scatterplot(data=df, x='Parada', y='elapsed',hue="Parada",palette="tab10").set_xticks(df["Parada"])
plt.title("Time distribution for each stop from previous stop")
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()

# %% [markdown]
# ## identify trends between time elapsed and time of day + find trends with stops

# %%
#kmeans dist

km = KMeans(n_clusters=df["Parada"].unique().size, init='random', n_init=20, max_iter=200, random_state=seed)
km.fit(df_c)
df_c['label'] = km.labels_
sns.scatterplot(data=df_c, x='elapsed', y='Time_Seconds', hue='label',palette="tab10")
sns.scatterplot(x=km.cluster_centers_[:, 0], y=km.cluster_centers_[:,1], color='red', marker='x')
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.title("KMeans")
plt.show()

df_c = df[['elapsed', 'Time_Seconds']]
#dbscan
#uses scaled data

gmm = GaussianMixture(n_components=df["Parada"].unique().size, max_iter=200)
gmm_cluster_labels = gmm.fit_predict(df_c)
df_c['label'] = gmm_cluster_labels
sns.scatterplot(data=df_c, x='elapsed', y='Time_Seconds', hue='label',palette="tab10")
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.title("Gaussian Mix")
plt.show()

df_c = df[['elapsed', 'Time_Seconds']]

#actual distribution
sns.scatterplot(data=df, x='elapsed', y='Time_Seconds', hue='Parada',palette="tab10")
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.title("Paradas prelabeled")
plt.show()
